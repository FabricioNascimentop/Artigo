# %%
import pandas as pd

dfEtnia = pd.read_csv('dados_prontos/etnia_cadunico_tratado.csv')


dfEtnia = dfEtnia[dfEtnia['RI'] == 'Guamá']
dfEtniaCenso = dfEtnia[(dfEtnia['Ano'] == 2012) | (dfEtnia['Ano'] == 2022)]
dfEtniaCenso.head(6)
# Out:
#      Codigo  Municipio  Brancos  Pretos  Amarelos  Pardos  Indigenas  NoData  \
# 490  150240  CASTANHAL    10030    3300       213   79294         59     379
# 500  150240  CASTANHAL    13981    4310       369   91126         52      16
# 518  150260    COLARES      656     210         8    6925          2      35
# 528  150260    COLARES     1553     304        44    7652          6       1
# 616  150290     CURUÇÁ     1703     290        70   22630          4     119
# 626  150290     CURUÇÁ     3611     566       155   27544         86       3
#
#       Ano     RI
# 490  2012  Guamá
# 500  2022  Guamá
# 518  2012  Guamá
# 528  2022  Guamá
# 616  2012  Guamá
# 626  2022  Guamá

# %%
import pandas as pd
import plotly.express as px

# Categorias que serão visualizadas
categorias = [
    "Brancos",
    "Pretos",
    "Amarelos",
    "Pardos",
    "Indigenas"
]

# Criar dataframe em formato longo
df_long = dfEtniaCenso.melt(
    id_vars=["Codigo", "Municipio", "Ano", "RI"],
    value_vars=categorias,
    var_name="Raça/Cor",
    value_name="Quantidade"
)

fig = px.bar(
    df_long,
    x="Municipio",
    y="Quantidade",
    color="Raça/Cor",
    facet_row="Ano",
    hover_data={
        "Municipio": True,
        "RI": True,
        "Ano": True,
        "Quantidade": ":,.0f"
    },
    title="Composição racial dos municípios do Pará",
    labels={
        "Municipio": "Município",
        "Quantidade": "Quantidade de pessoas",
        "Raça/Cor": "Raça/Cor"
    },
    barmode="group"
)

fig.update_layout(
    height=900,
    xaxis_tickangle=-45,
    legend_title="Raça/Cor",
    hovermode="x unified"
)

fig.show()

# %%
dfSexo = pd.read_csv('dados_prontos/sexo_cadunico_tratado.csv')

dfSexoCenso = dfSexo[(dfSexo['Ano'] == 2012) | (dfSexo['Ano'] == 2022)]
dfSexoCenso
# Out:
#       Codigo         Municipio  Homens  Mulheres   Ano         RI
# 3     150010        ABAETETUBA   62504     70334  2022  Tocantins
# 13    150010        ABAETETUBA   48019     53970  2012  Tocantins
# 17    150013   ABEL FIGUEIREDO    2592      3060  2022  Rio Capim
# 27    150013   ABEL FIGUEIREDO    2198      2594  2012  Rio Capim
# 31    150020             ACARÁ   22480     25332  2022  Tocantins
# ...      ...               ...     ...       ...   ...        ...
# 1983  150830             VISEU   22674     23329  2022  Rio Caeté
# 1987  150835  VITÓRIA DO XINGU    3668      3767  2012      Xingu
# 1997  150835  VITÓRIA DO XINGU    5339      6195  2022      Xingu
# 2004  150840          XINGUARA   11446     14885  2022   Araguaia
# 2014  150840          XINGUARA    8382     10459  2012   Araguaia
#
# [287 rows x 6 columns]

# %%
dfIdade = pd.read_csv('dados_prontos/faixa_etaria_cadunico_tratado.csv')

dfIdade.head(2)
# Out:
#    Codigo   Municipio     0-3     4-6   7-15  16-17  18-24  25-34  35-39  \
# 0  150010  ABAETETUBA     NaN     NaN  23682   5901  17267  16374   6321
# 1  150010  ABAETETUBA  8003.0  7623.0  22397   5209  16639  22497   9846
#
#    40-44  45-49  50-54  55-59  60-64   64+   Total   Ano         RI
# 0   5287   4110   3211   2520   1671  2455   88799  2012  Tocantins
# 1   7485   9821   6690   5278   3979  6896  132363  2026  Tocantins
