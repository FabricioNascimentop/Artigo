# %%
import pandas as pd

df = pd.read_csv('dados_tratados/etnia_ibge.csv')
df
# Out:
#       Codigo                Municipio  Branca  Preta  Amarela   Parda  \
# 0    1500107          Abaetetuba (PA)   30676   9038      797  100509
# 1    1500131     Abel Figueiredo (PA)    1655    699       88    4327
# 2    1500206               Acará (PA)    5985   4081      556   42900
# 3    1500305                Afuá (PA)    6826   1135      138   26942
# 4    1500347  Água Azul do Norte (PA)    6788   1935      844   15486
# ..       ...                      ...     ...    ...      ...     ...
# 138  1508159              Uruará (PA)   11896   3325      459   29071
# 139  1508209               Vigia (PA)   11119   1877      229   34645
# 140  1508308               Viseu (PA)    8954   3131      602   43983
# 141  1508357    Vitória do Xingu (PA)    3016   1061      306    8919
# 142  1508407            Xinguara (PA)   10924   3062      801   25737
#
#     Indígena   Total
# 0         80  141100
# 1         11    6780
# 2         47   53569
# 3          1   35042
# ...
