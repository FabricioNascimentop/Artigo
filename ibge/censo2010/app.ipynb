# %%
import pandas as pd

df = pd.read_csv('dados_tratados/faixa_etaria_ibge_2010_tratado.csv')
df
# Out:
#      Codigo              Municipio     0-3     4-6     7-15   16-17    18-24  \
# 0        15                   Pará  584197  459462  1477017  318551  1051358
# 1    150010        Abaetetuba (PA)   10342    8118    28235    6820    21305
# 2    150013   Abel Figueiredo (PA)     532     413     1328     277      885
# 3    150020             Acará (PA)    4935    3856    11952    2438     7489
# 4    150030              Afuá (PA)    3657    2889     8897    1740     4752
# ..      ...                    ...     ...     ...      ...     ...      ...
# 139  150815            Uruará (PA)    3853    2899     8995    1884     6200
# 140  150820             Vigia (PA)    3409    2791     9043    2125     6763
# 141  150830             Viseu (PA)    5682    4473    13338    2627     7546
# 142  150835  Vitória do Xingu (PA)     942     809     2676     546     2080
# 143  150840          Xinguara (PA)    2984    2350     7665    1601     5555
#
# ...
