# %%
from pathlib import Path

print(Path.cwd())
# Out:
# /home/fabricio_nascimento/Área de trabalho/dev/Artigo/ibge

# %%
import pandas as pd

dfEtnia2010 = pd.read_csv('censo2010/dados_tratados/etnia_ibge_2010_tratado.csv')
dfEtnia2010
# Out:
#      Codigo                Municipio  Branca  Preta  Amarela   Parda Indígena  \
# 0    150010          Abaetetuba (PA)   30676   9038      797  100509       80
# 1    150013     Abel Figueiredo (PA)    1655    699       88    4327       11
# 2    150020               Acará (PA)    5985   4081      556   42900       47
# 3    150030                Afuá (PA)    6826   1135      138   26942        1
# 4    150034  Água Azul do Norte (PA)    6788   1935      844   15486        4
# ..      ...                      ...     ...    ...      ...     ...      ...
# 138  150815              Uruará (PA)   11896   3325      459   29071       38
# 139  150820               Vigia (PA)   11119   1877      229   34645       19
# 140  150830               Viseu (PA)    8954   3131      602   43983       46
# 141  150835    Vitória do Xingu (PA)    3016   1061      306    8919      129
# 142  150840            Xinguara (PA)   10924   3062      801   25737       49
#
#       Total         RI   Ano
# ...

# %%
dfEtnia2022 = pd.read_csv('censo2022/dados_tratados/etnia_ibge_2022_tratado.csv')

dfEtnia2022
# Out:
#      Codigo              Municipio   Branca   Preta Amarela    Parda  \
# 0         1                   Pará  1570281  793621   12432  5673446
# 1    150010        Abaetetuba (PA)    29624   15895     107   112187
# 2    150013   Abel Figueiredo (PA)     1228     640       -     4258
# 3    150020             Acará (PA)     5684    8503      65    44748
# 4    150030              Afuá (PA)     5470    2567      24    29690
# ..      ...                    ...      ...     ...     ...      ...
# 140  150815            Uruará (PA)     9503    4409      11    29535
# 141  150820             Vigia (PA)    10924    3632      24    36224
# 142  150830             Viseu (PA)     6782    3385      24    48435
# 143  150835  Vitória do Xingu (PA)     2730    1666      24    10667
# 144  150840          Xinguara (PA)    12369    4933      69    35466
#
#      Indígena    Total         RI   Ano
# 0       69180  8120131        NaN  2022
# 1          83   158188  Tocantins  2022
# ...

# %%
dfEtniaJunto = pd.concat([dfEtnia2010,dfEtnia2022])

dfEtniaJunto.to_csv('panorama1020/etnia_ibge.csv',index=False)

# %%
dfIdade2010 = pd.read_csv('censo2010/dados_tratados/faixa_etaria_ibge_2010_tratado.csv')
dfIdade2010
# Out:
#      Codigo              Municipio     0-3     4-6     7-15   16-17    18-24  \
# 0        15                   Pará  584197  459462  1477017  318551  1051358
# 1    150010        Abaetetuba (PA)   10342    8118    28235    6820    21305
# 2    150013   Abel Figueiredo (PA)     532     413     1328     277      885
# 3    150020             Acará (PA)    4935    3856    11952    2438     7489
# 4    150030              Afuá (PA)    3657    2889     8897    1740     4752
# ..      ...                    ...     ...     ...      ...     ...      ...
# 139  150815            Uruará (PA)    3853    2899     8995    1884     6200
# 140  150820             Vigia (PA)    3409    2791     9043    2125     6763
# 141  150830             Viseu (PA)    5682    4473    13338    2627     7546
# 142  150835  Vitória do Xingu (PA)     942     809     2676     546     2080
# 143  150840          Xinguara (PA)    2984    2350     7665    1601     5555
#
# ...

# %%
dfIdade2022 = pd.read_csv('censo2022/dados_tratados/faixa_etaria_ibge_2022_tratado.csv')
dfIdade2022
# Out:
#      Codigo              Municipio     0-3     4-6     7-15   16-17   18-24  \
# 0        15                   Pará  538275  421518  1298790  292959  994826
# 1    150010        Abaetetuba (PA)   10459    8071    24556    5591   20296
# 2    150013   Abel Figueiredo (PA)     425     373     1001     202     667
# 3    150020             Acará (PA)    4278    3372    10659    2510    7275
# 4    150030              Afuá (PA)    3512    2693     7775    1630    5170
# ..      ...                    ...     ...     ...      ...     ...     ...
# 140  150815            Uruará (PA)    3343    2474     7447    1591    5224
# 141  150820             Vigia (PA)    2944    2382     7517    1793    5651
# 142  150830             Viseu (PA)    4342    3492    11827    2701    7406
# 143  150835  Vitória do Xingu (PA)    1087     962     2856     608    1783
# 144  150840          Xinguara (PA)    3713    2832     8213    1816    6658
#
# ...

# %%
dfIdadeJunto = pd.concat([dfIdade2010,dfIdade2022])

dfIdadeJunto
# Out:
#      Codigo              Municipio     0-3     4-6     7-15   16-17    18-24  \
# 0        15                   Pará  584197  459462  1477017  318551  1051358
# 1    150010        Abaetetuba (PA)   10342    8118    28235    6820    21305
# 2    150013   Abel Figueiredo (PA)     532     413     1328     277      885
# 3    150020             Acará (PA)    4935    3856    11952    2438     7489
# 4    150030              Afuá (PA)    3657    2889     8897    1740     4752
# ..      ...                    ...     ...     ...      ...     ...      ...
# 140  150815            Uruará (PA)    3343    2474     7447    1591     5224
# 141  150820             Vigia (PA)    2944    2382     7517    1793     5651
# 142  150830             Viseu (PA)    4342    3492    11827    2701     7406
# 143  150835  Vitória do Xingu (PA)    1087     962     2856     608     1783
# 144  150840          Xinguara (PA)    3713    2832     8213    1816     6658
#
# ...

# %%
dfIdadeJunto.to_csv('panorama1020/faixa_etaria_ibge.csv',index=False)

# %%
dfSexo2010 = pd.read_csv('censo2010/dados_tratados/sexo_ibge_2010_tratado.csv')
dfSexo2010
# Out:
#      Codigo              Municipio   Homens  Mulheres    Total         RI  \
# 0         1                   Pará  3821837   3759214  7581051        NaN
# 1    150010        Abaetetuba (PA)    71630     69470   141100  Tocantins
# 2    150013   Abel Figueiredo (PA)     3533      3247     6780  Rio Capim
# 3    150020             Acará (PA)    28115     25454    53569  Tocantins
# 4    150030              Afuá (PA)    18453     16589    35042     Marajó
# ..      ...                    ...      ...       ...      ...        ...
# 139  150815            Uruará (PA)    23633     21156    44789      Xingu
# 140  150820             Vigia (PA)    24548     23341    47889      Guamá
# 141  150830             Viseu (PA)    29817     26899    56716  Rio Caeté
# 142  150835  Vitória do Xingu (PA)     7281      6150    13431      Xingu
# 143  150840          Xinguara (PA)    20572     20001    40573   Araguaia
#
#       Ano
# 0    2010
# 1    2010
# 2    2010
# 3    2010
# 4    2010
# ...

# %%
dfSexo2022 = pd.read_csv('censo2022/dados_tratados/sexo_ibge_2022_tratado.csv')
dfSexo2022
# Out:
#      Codigo              Municipio    Homens   Mulheres      Total         RI  \
# 0         0                 Brasil  98532431  104548325  203080756        NaN
# 1         1                   Pará   4051813    4068318    8120131        NaN
# 2    150010        Abaetetuba (PA)     79297      78891     158188  Tocantins
# 3    150013   Abel Figueiredo (PA)      3113       3023       6136  Rio Capim
# 4    150020             Acará (PA)     30551      28472      59023  Tocantins
# ..      ...                    ...       ...        ...        ...        ...
# 141  150815            Uruará (PA)     22812      20746      43558      Xingu
# 142  150820             Vigia (PA)     25695      25137      50832      Guamá
# 143  150830             Viseu (PA)     30472      28220      58692  Rio Caeté
# 144  150835  Vitória do Xingu (PA)      8031       7576      15607      Xingu
# 145  150840          Xinguara (PA)     26590      26303      52893   Araguaia
#
#       Ano
# 0    2022
# ...

# %%
dfSexoJunto = pd.concat([dfSexo2022,dfSexo2010])

dfSexoJunto.to_csv('panorama1020/sexo_ibge.csv',index=False)

# %%
dfUrbe2010 = pd.read_csv('censo2010/dados_tratados/urbano_rural_ibge_2010_tratado.csv')
dfUrbe2010
# Out:
#      Codigo                Município  Urbana  Rural   Total         RI   Ano
# 0    150010          Abaetetuba (PA)   82998  58102  141100  Tocantins  2010
# 1    150013     Abel Figueiredo (PA)    6034    746    6780  Rio Capim  2010
# 2    150020               Acará (PA)   12621  40948   53569  Tocantins  2010
# 3    150030                Afuá (PA)    9478  25564   35042     Marajó  2010
# 4    150034  Água Azul do Norte (PA)    4876  20181   25057   Araguaia  2010
# ..      ...                      ...     ...    ...     ...        ...   ...
# 138  150815              Uruará (PA)   24430  20359   44789      Xingu  2010
# 139  150820               Vigia (PA)   32353  15536   47889      Guamá  2010
# 140  150830               Viseu (PA)   18397  38319   56716  Rio Caeté  2010
# 141  150835    Vitória do Xingu (PA)    5362   8069   13431      Xingu  2010
# 142  150840            Xinguara (PA)   31492   9081   40573   Araguaia  2010
#
# [143 rows x 7 columns]

# %%
dfUrbe2022 = pd.read_csv('censo2022/dados_tratados/urbano_rural_ibge_2022_tratado.csv')
dfUrbe2022
# Out:
#      Codigo              Municipio     Urbana     Rural      Total         RI  \
# 0         0                 Brasil  177508417  25572339  203080756        NaN
# 1         1                   Pará    6095530   2024601    8120131        NaN
# 2    150010        Abaetetuba (PA)      98390     59798     158188  Tocantins
# 3    150013   Abel Figueiredo (PA)       5366       770       6136  Rio Capim
# 4    150020             Acará (PA)      13079     45944      59023  Tocantins
# ..      ...                    ...        ...       ...        ...        ...
# 141  150815            Uruará (PA)      25678     17880      43558      Xingu
# 142  150820             Vigia (PA)      39596     11236      50832      Guamá
# 143  150830             Viseu (PA)      29936     28756      58692  Rio Caeté
# 144  150835  Vitória do Xingu (PA)       8700      6907      15607      Xingu
# 145  150840          Xinguara (PA)      46390      6503      52893   Araguaia
#
#       Ano
# 0    2022
# ...

# %%
dfUrbeJunto = pd.concat([dfUrbe2010,dfUrbe2022])

dfUrbeJunto.to_csv('panorama1020/urbano_rural_ibge.csv',index=False)
