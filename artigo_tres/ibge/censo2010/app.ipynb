# %%
import pandas as pd

df = pd.read_csv('dados_tratados/urbana_rural_ibge.csv')
df
# Out:
#       Codigo                Município  Urbana  Rural   Total
# 0    1500107          Abaetetuba (PA)   82998  58102  141100
# 1    1500131     Abel Figueiredo (PA)    6034    746    6780
# 2    1500206               Acará (PA)   12621  40948   53569
# 3    1500305                Afuá (PA)    9478  25564   35042
# 4    1500347  Água Azul do Norte (PA)    4876  20181   25057
# ..       ...                      ...     ...    ...     ...
# 138  1508159              Uruará (PA)   24430  20359   44789
# 139  1508209               Vigia (PA)   32353  15536   47889
# 140  1508308               Viseu (PA)   18397  38319   56716
# 141  1508357    Vitória do Xingu (PA)    5362   8069   13431
# 142  1508407            Xinguara (PA)   31492   9081   40573
#
# [143 rows x 5 columns]
